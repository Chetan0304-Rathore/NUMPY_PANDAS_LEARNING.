# %%
# CREATING A DATAFRAMES

# %%
import numpy as np 
import pandas as pd

# %%
data ={
    'NAME': ['JOHN','MOTU','PATLU','HARI'],
    'AGE':[34,30,28,25],
    'CITY':['NEW YORK','UK','PARIES','BHOPAL'],
    'SALARY':[65000,70000,50000,20000]

}
d1 = pd.DataFrame(data)
d1
# Out:
#     NAME  AGE      CITY  SALARY
# 0   JOHN   34  NEW YORK   65000
# 1   MOTU   30        UK   70000
# 2  PATLU   28    PARIES   50000
# 3   HARI   25    BHOPAL   20000

# %%
# create  a dataframes in list

# %%
data_list = [
    ["Ram ",34, "bhopal",5000],
    ["chetan",21 ,"indore",10000],
    ["hari",22,"delhi",16000]
]
d2= pd.DataFrame(data_list)
d2
# Out:
#         0   1       2      3
# 0    Ram   34  bhopal   5000
# 1  chetan  21  indore  10000
# 2    hari  22   delhi  16000

# %%
column = ["NAME","AGE","CITY","SALARY"]
d2=pd.DataFrame(data_list,columns=column)
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000
# 2    hari   22   delhi   16000

# %%
# selecting or indexing the dataframe

# %%
d2["NAME"]
# Out:
# 0      Ram
# 1    chetan
# 2      hari
# Name: NAME, dtype: object

# %%
# SELCET MULTIPLE COLUMNS IN DATAFRAME

# %%
d2 [["NAME","AGE","CITY","SALARY"]]
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000
# 2    hari   22   delhi   16000

# %%
# CREATING A NEW COLUMN IN DATAFRAME

# %%
d2["designation"] = ["doctor","eng","teacher"]
d2
# Out:
#      NAME  AGE    CITY  SALARY designation
# 0    Ram    34  bhopal    5000      doctor
# 1  chetan   21  indore   10000         eng
# 2    hari   22   delhi   16000     teacher

# %%
d2
# Out:
#      NAME  AGE    CITY  SALARY designation
# 0    Ram    34  bhopal    5000      doctor
# 1  chetan   21  indore   10000         eng
# 2    hari   22   delhi   16000     teacher

# %%
d2
# Out:
#      NAME  AGE    CITY  SALARY designation
# 0    Ram    34  bhopal    5000      doctor
# 1  chetan   21  indore   10000         eng
# 2    hari   22   delhi   16000     teacher

# %%
# removing columns in datafarme

# %%
d2.drop("designation",axis=1)
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000
# 2    hari   22   delhi   16000

# %%
d2
# Out:
#      NAME  AGE    CITY  SALARY designation
# 0    Ram    34  bhopal    5000      doctor
# 1  chetan   21  indore   10000         eng
# 2    hari   22   delhi   16000     teacher

# %%
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000
# 2    hari   22   delhi   16000

# %%
d2.drop("SALARY",axis=1,inplace=True)
d2
# Out:
#      NAME  AGE    CITY
# 0    Ram    34  bhopal
# 1  chetan   21  indore
# 2    hari   22   delhi

# %%
# again add the new column

# %%
d2["SALARY"] = [50000,100000,120000]
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal   50000
# 1  chetan   21  indore  100000
# 2    hari   22   delhi  120000

# %%
# removing the row

# %%
d2.drop(2,axis=0,inplace=True)
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal   50000
# 1  chetan   21  indore  100000

# %%
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal   50000
# 1  chetan   21  indore  100000

# %%
data_list = [
    ["Ram ",34, "bhopal",5000],
    ["chetan",21 ,"indore",10000],
    ["hari",22,"delhi",16000]
]
d2= pd.DataFrame(data_list)
d2
# Out:
#         0   1       2      3
# 0    Ram   34  bhopal   5000
# 1  chetan  21  indore  10000
# 2    hari  22   delhi  16000

# %%
column = ["NAME","AGE","CITY","SALARY"]
d2=pd.DataFrame(data_list,columns=column)
d2
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000
# 2    hari   22   delhi   16000

# %%
# selecting a row

# %%
d2.loc[0]
# Out:
# NAME        Ram
# AGE           34
# CITY      bhopal
# SALARY      5000
# Name: 0, dtype: object

# %%
d2.loc[[0,1]]
# Out:
#      NAME  AGE    CITY  SALARY
# 0    Ram    34  bhopal    5000
# 1  chetan   21  indore   10000

# %%
# SLECTING SUBSETS OF ROWS AND COLUMS 

d2.loc[[0,1]][["CITY","SALARY"]]
# Out:
#      CITY  SALARY
# 0  bhopal    5000
# 1  indore   10000

# %%
# SELECTS NAME AND AGE COLUMNS

# %%
d2.loc[[0,1,2]][["NAME","AGE"]]
# Out:
#      NAME  AGE
# 0    Ram    34
# 1  chetan   21
# 2    hari   22

# %%
# CONDITIONAL SELECTION

# %%
# i only want tpo see those people whose ag eis above 30.
d2[d2["AGE"]>30]
# Out:
#    NAME  AGE    CITY  SALARY
# 0  Ram    34  bhopal    5000

# %%
# i only want tpo see those people whose ag eis above 30 ,and city is paris
d2[(d2["AGE"]>30) & (d2["CITY"]=="bhopal")]
# Out:
#    NAME  AGE    CITY  SALARY
# 0  Ram    34  bhopal    5000
