# %%
import numpy as np 
import pandas as pd

# %%
# create a series

# %%
my_list = ['a','b','c']

# %%
pd.Series(my_list)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
arr = np.array([10,20 ,30])
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
d = {1:"chetan", 2:"hari",3:"rohan"}

# %%
pd.Series(d)
# Out:
# 1    chetan
# 2      hari
# 3     rohan
# dtype: object
