# %%
import numpy  as  np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x
y = x**2 
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
#  subplots 


plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %%
# perform the opertaion in first plot 
plt.subplot(2,2,1)
plt.plot(x,y)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
x = np.linspace(0,5,11)
x
y = x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.title("graph")
plt.xlabel("X - axis")
plt.plot("y -axis")
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
# OBJECT ORENTED WAY 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
x = np.linspace(0,5,11)
x
y = x**2
y

# %%
fig =plt.figure(figsize =(20,80),dpi=500)
axis1 = fig.add_axes([0.1,0.1,1,1])
axis1.plot(x,y)
axis2 = fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)
