# %%
print("hello world ")
# Out:
# hello world

# %%
a = 2 

b = 3 

print (a+b)
# Out:
# 5

# %%
def helllo():
    print ("hello ram")
helllo()
# Out:
# hello ram

# %%
a =array ([2,6,9])
b=array([9,3,5])
print(a+b)
